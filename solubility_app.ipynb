# %%
# !pip install streamlit
# Out:
# DEPRECATION: Python 2.7 reached the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 is no longer maintained. pip 21.0 will drop support for Python 2.7 in January 2021. More details about Python 2 support in pip can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support pip 21.0 will remove support for this functionality.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-0.55.2-py2.py3-none-any.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 568 kB/s eta 0:00:01
# Collecting click>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 483 kB/s eta 0:00:01
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.6.2-py2.py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 533 kB/s eta 0:00:01
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 591 kB/s eta 0:00:01
# Collecting botocore
#   Downloading botocore-1.20.112-py2.py3-none-any.whl (7.7 MB)
#      |████████████████████████████████| 7.7 MB 397 kB/s eta 0:00:01
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.17.3-cp27-cp27m-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 605 kB/s eta 0:00:01
# Collecting boto3
#   Downloading boto3-1.17.112-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 488 kB/s eta 0:00:01
# Collecting validators
#   Downloading validators-0.14.2.tar.gz (25 kB)
# Collecting base58
#   Downloading base58-1.0.3-py2-none-any.whl (3.1 kB)
# Collecting requests
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 428 kB/s eta 0:00:01
# Collecting tornado<6.0,>=5.0
#   Downloading tornado-5.1.1.tar.gz (516 kB)
#      |████████████████████████████████| 516 kB 548 kB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-6.2.2-cp27-cp27m-macosx_10_6_intel.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 1.5 MB/s ta 0:00:012
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting python-dateutil<=2.8.0
#   Downloading python_dateutil-2.8.0-py2.py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 531 kB/s eta 0:00:01
# Collecting altair>=3.2.0
#   Downloading altair-3.3.0-py2.py3-none-any.whl (603 kB)
#      |████████████████████████████████| 603 kB 576 kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.21.0 in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from streamlit) (0.24.2)
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting enum-compat
#   Downloading enum-compat-0.0.3.tar.gz (1.4 kB)
# Requirement already satisfied: numpy in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from streamlit) (1.8.0rc1)
# Requirement already satisfied: future in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from streamlit) (0.17.1)
# Collecting watchdog
#   Downloading watchdog-0.10.7.tar.gz (102 kB)
#      |████████████████████████████████| 102 kB 617 kB/s eta 0:00:01
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 527 kB/s eta 0:00:01
# Collecting ipython>=5.8.0; python_version < "3.4"
#   Downloading ipython-5.10.0-py2-none-any.whl (760 kB)
#      |████████████████████████████████| 760 kB 580 kB/s eta 0:00:01
# Collecting traitlets>=4.3.2
#   Downloading traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 655 kB/s eta 0:00:01
# Collecting jinja2>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 576 kB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 583 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.9 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from protobuf>=3.6.0->streamlit) (1.12.0)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 620 kB/s eta 0:00:01
# Collecting decorator>=3.4.0
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 563 kB/s eta 0:00:01
# Collecting idna<3,>=2.5; python_version < "3"
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 622 kB/s eta 0:00:01
# Collecting chardet<5,>=3.0.2; python_version < "3"
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 628 kB/s eta 0:00:01
# Collecting futures
#   Downloading futures-3.3.0-py2-none-any.whl (16 kB)
# Collecting singledispatch
#   Downloading singledispatch-3.7.0-py2.py3-none-any.whl (9.2 kB)
# Collecting backports_abc>=0.4
#   Downloading backports_abc-0.5-py2.py3-none-any.whl (5.2 kB)
# Collecting jsonschema
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 621 kB/s eta 0:00:01
# Collecting typing>=3.6; python_version < "3.5"
#   Downloading typing-3.10.0.0-py2-none-any.whl (26 kB)
# Collecting toolz
#   Downloading toolz-0.10.0.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 664 kB/s eta 0:00:01
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz>=2011k in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from pandas>=0.21.0->streamlit) (2013.7)
# Requirement already satisfied: enum34 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from enum-compat->streamlit) (1.1.6)
# Collecting pathtools>=0.1.1
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-4.4.0-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 543 kB/s eta 0:00:01
# Collecting ipython-genutils~=0.2.0
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 611 kB/s eta 0:00:01
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-4.10.1-py2-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 622 kB/s eta 0:00:01
# Collecting backports.shutil-get-terminal-size; python_version == "2.7"
#   Downloading backports.shutil_get_terminal_size-1.0.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pathlib2; python_version == "2.7" or python_version == "3.3" in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from ipython>=5.8.0; python_version < "3.4"->pydeck>=0.1.dev5->streamlit) (2.3.6)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py2-none-any.whl (245 kB)
#      |████████████████████████████████| 245 kB 600 kB/s eta 0:00:01
# Requirement already satisfied: setuptools>=18.5 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from ipython>=5.8.0; python_version < "3.4"->pydeck>=0.1.dev5->streamlit) (41.0.1)
# Collecting pexpect; sys_platform != "win32"
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 561 kB/s eta 0:00:01
# Collecting pygments<2.6
#   Downloading Pygments-2.5.2-py2.py3-none-any.whl (896 kB)
#      |████████████████████████████████| 896 kB 625 kB/s eta 0:00:01
# Collecting simplegeneric>0.8
#   Downloading simplegeneric-0.8.1.zip (12 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting appnope; sys_platform == "darwin"
#   Downloading appnope-0.1.2-py2.py3-none-any.whl (4.3 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp27-cp27m-macosx_10_6_intel.whl (17 kB)
# Collecting functools32; python_version < "3"
#   Downloading functools32-3.2.3-2.tar.gz (31 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.16.1.tar.gz (108 kB)
#      |████████████████████████████████| 108 kB 591 kB/s eta 0:00:01
# Collecting attrs>=17.4.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 586 kB/s eta 0:00:01
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from jsonschema->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: configparser>=3.5; python_version == "2.7" in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from entrypoints->altair>=3.2.0->streamlit) (4.0.2)
# Collecting jupyter-core
#   Downloading jupyter_core-4.6.3-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 554 kB/s eta 0:00:01
# Collecting notebook>=4.4.1
#   Downloading notebook-5.7.13-py2.py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 574 kB/s eta 0:00:01
# Collecting jupyter-client
#   Downloading jupyter_client-5.3.5-py2.py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 302 kB/s eta 0:00:01
# Requirement already satisfied: scandir; python_version < "3.5" in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from pathlib2; python_version == "2.7" or python_version == "3.3"->ipython>=5.8.0; python_version < "3.4"->pydeck>=0.1.dev5->streamlit) (1.10.0)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contextlib2; python_version < "3" in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair>=3.2.0->streamlit) (0.6.0.post1)
# Requirement already satisfied: zipp>=0.5 in /Users/rohanmunshi/Library/Python/2.7/lib/python/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair>=3.2.0->streamlit) (1.2.0)
# Collecting pyzmq>=17
#   Downloading pyzmq-19.0.2-cp27-cp27m-macosx_10_9_intel.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 706 kB/s eta 0:00:01
# Collecting Send2Trash
#   Downloading Send2Trash-1.8.0.tar.gz (13 kB)
# Requirement already satisfied: ipaddress; python_version == "2.7" in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.22)
# Collecting nbconvert<6.0
#   Downloading nbconvert-5.6.1-py2.py3-none-any.whl (455 kB)
#      |████████████████████████████████| 455 kB 576 kB/s eta 0:00:01
# Collecting terminado>=0.8.1
#   Downloading terminado-0.8.3-py2.py3-none-any.whl (33 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 678 kB/s eta 0:00:01
# Collecting backports.functools-lru-cache>=1.2.1; python_version < "3.2"
#   Downloading backports.functools_lru_cache-1.6.4-py2.py3-none-any.whl (5.9 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting bleach
#   Downloading bleach-3.3.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 554 kB/s eta 0:00:01
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 556 kB/s eta 0:00:01
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 600 kB/s eta 0:00:01
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 629 kB/s eta 0:00:01
# Building wheels for collected packages: blinker, validators, tornado, enum-compat, watchdog, toolz, pathtools, simplegeneric, functools32, pyrsistent, Send2Trash
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py2-none-any.whl size=13451 sha256=27f8f14e04ae58beb4bb9f2cac40dd1ba7a587d37ade1e55f062f426130204be
#   Stored in directory: /Users/rohanmunshi/Library/Caches/pip/wheels/7b/1f/a0/7ce496c69b9be7cef75645749e256d5ef2dc9d08336f92248b
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0
# Installing collected packages: click, ipython-genutils, decorator, traitlets, functools32, pyrsistent, attrs, jsonschema, jupyter-core, nbformat, backports.shutil-get-terminal-size, backports.functools-lru-cache, wcwidth, prompt-toolkit, ptyprocess, pexpect, pygments, simplegeneric, pickleshare, appnope, ipython, futures, singledispatch, backports-abc, tornado, python-dateutil, pyzmq, jupyter-client, ipykernel, Send2Trash, MarkupSafe, jinja2, mistune, defusedxml, entrypoints, webencodings, pyparsing, packaging, bleach, pandocfilters, testpath, nbconvert, terminado, prometheus-client, notebook, widgetsnbextension, ipywidgets, pydeck, blinker, jmespath, urllib3, botocore, protobuf, s3transfer, boto3, validators, base58, certifi, idna, chardet, requests, pillow, toml, typing, toolz, altair, tzlocal, astor, enum-compat, pathtools, watchdog, streamlit
#   WARNING: The script jsonschema is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter, jupyter-migrate and jupyter-troubleshoot are installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-trust is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pygmentize is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts iptest, iptest2, ipython and ipython2 are installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   WARNING: The scripts jupyter-kernel, jupyter-kernelspec and jupyter-run are installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script send2trash is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-nbconvert is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-bundlerextension, jupyter-nbextension, jupyter-notebook and jupyter-serverextension are installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script base58 is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script chardetect is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchmedo is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit is installed in '/Users/rohanmunshi/Library/Python/2.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# matplotlib 1.3.1 requires nose, which is not installed.
# pydeck 0.6.2 requires numpy>=1.16.4, but you'll have numpy 1.8.0rc1 which is incompatible.
# pandas 0.24.2 requires numpy>=1.12.0, but you'll have numpy 1.8.0rc1 which is incompatible.
# Successfully installed MarkupSafe-1.1.1 Send2Trash-1.8.0 altair-3.3.0 appnope-0.1.2 astor-0.8.1 attrs-21.2.0 backports-abc-0.5 backports.functools-lru-cache-1.6.4 backports.shutil-get-terminal-size-1.0.0 base58-1.0.3 bleach-3.3.1 blinker-1.4 boto3-1.17.112 botocore-1.20.112 certifi-2021.10.8 chardet-4.0.0 click-7.1.2 decorator-4.4.2 defusedxml-0.7.1 entrypoints-0.3 enum-compat-0.0.3 functools32-3.2.3.post2 futures-3.3.0 idna-2.10 ipykernel-4.10.1 ipython-5.10.0 ipython-genutils-0.2.0 ipywidgets-7.6.5 jinja2-2.11.3 jmespath-0.10.0 jsonschema-3.2.0 jupyter-client-5.3.5 jupyter-core-4.6.3 mistune-0.8.4 nbconvert-5.6.1 nbformat-4.4.0 notebook-5.7.13 packaging-20.9 pandocfilters-1.5.0 pathtools-0.1.2 pexpect-4.8.0 pickleshare-0.7.5 pillow-6.2.2 prometheus-client-0.11.0 prompt-toolkit-1.0.18 protobuf-3.17.3 ptyprocess-0.7.0 pydeck-0.6.2 pygments-2.5.2 pyparsing-2.4.7 pyrsistent-0.16.1 python-dateutil-2.8.0 pyzmq-19.0.2 requests-2.26.0 s3transfer-0.4.2 simplegeneric-0.8.1 singledispatch-3.7.0 streamlit-0.55.2 terminado-0.8.3 testpath-0.4.4 toml-0.10.2 toolz-0.10.0 tornado-5.1.1 traitlets-4.3.3 typing-3.10.0.0 tzlocal-2.1 urllib3-1.26.7 validators-0.14.2 watchdog-0.10.7 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.5.1

# %%
import numpy as np
import pandas as pd
import streamlit as st
import pickle
from PIL import Image
from rdkit import Chem
from rdkit.Chem import Descriptors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-63822121c65d> in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import streamlit as st
#       4 import pickle
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'streamlit'
